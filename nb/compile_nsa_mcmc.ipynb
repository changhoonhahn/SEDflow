# %% [markdown]
# # Compile MCMC samples of posteriors for select NSA galaxies

# %%
import numpy as np 
from sedflow import obs as Obs
from sedflow import train as Train

# %%
nsa, igals = Obs.NSA()
