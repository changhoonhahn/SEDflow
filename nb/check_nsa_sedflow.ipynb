# %%
import os
import h5py
import numpy as np
from sedflow import train as Train

# %%
# --- plotting --- 
import corner as DFM
import matplotlib as mpl
import matplotlib.pyplot as plt
#mpl.rcParams['text.usetex'] = True
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['axes.linewidth'] = 1.5
mpl.rcParams['axes.xmargin'] = 1
mpl.rcParams['xtick.labelsize'] = 'x-large'
mpl.rcParams['xtick.major.size'] = 5
mpl.rcParams['xtick.major.width'] = 1.5
mpl.rcParams['ytick.labelsize'] = 'x-large'
mpl.rcParams['ytick.major.size'] = 5
mpl.rcParams['ytick.major.width'] = 1.5
mpl.rcParams['legend.frameon'] = False

# %%
fsedflow = h5py.File(os.path.join(Train.data_dir(), 'nsa.sedflow.v0.2.hdf5'), 'r')

# %%
logm = fsedflow['log_mstar'][...]
logsfr = fsedflow['log_sfr_1gyr'][...]
logzmw = fsedflow['log_z_mw'][...]

# %%
logm_median = np.median(logm, axis=1)
logsfr_median = np.median(logsfr, axis=1)
logzmw_median = np.median(logzmw, axis=1)

# %%
fig = plt.figure(figsize=(6,4))
sub = fig.add_subplot(111)
_ = sub.hist(logm_median, range=(8, 12.5), bins=50)
sub.set_xlabel(r'$\log M_*$', fontsize=25)
sub.set_xlim(8., 12.5)
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
sub = fig.add_subplot(111)
sub.scatter(logm_median, logsfr_median, s=0.1)
sub.set_xlabel(r'$\log M_*$', fontsize=25)
sub.set_xlim(8, 13)
sub.set_ylabel(r'$\log SFR_{1\,Gyr}$', fontsize=25)
sub.set_ylim(-3, 3)
# Out:
# (-3.0, 3.0)

# %%
fig = plt.figure(figsize=(8,8))
sub = fig.add_subplot(111)
sub.scatter(logm_median, logsfr_median-logm_median, s=0.1)
sub.set_xlabel(r'$\log M_*$', fontsize=25)
sub.set_xlim(8, 13)
sub.set_ylabel(r'$\log sSFR_{1\,Gyr}$', fontsize=25)
# Out:
# Text(0, 0.5, '$\\log sSFR_{1\\,Gyr}$')

# %%
fig = plt.figure(figsize=(8,8))
sub = fig.add_subplot(111)
sub.scatter(logm_median, logzmw_median, s=0.1)
sub.set_xlabel(r'$\log M_*$', fontsize=25)
sub.set_xlim(8, 13)
sub.set_ylabel(r'$\log Z_{\rm MW}$', fontsize=25)
# Out:
# Text(0, 0.5, '$\\log Z_{\\rm MW}$')
